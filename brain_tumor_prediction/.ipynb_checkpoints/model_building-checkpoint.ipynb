# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
import os
import tqdm

# %%
# we will first create a class list to store the labels
labels=['yes','no']

# %%
data_dir='data'

# %%
# we will augment data 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#instantiate the ImageDataGenerator class
datagen = ImageDataGenerator(
        vertical_flip=True,
        horizontal_flip=True,
        fill_mode='nearest')
#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('data/', batch_size=6,target_size=(256,256),
                          save_to_dir='augment/', save_format='jpg'):
    if i==40:
        break
    i+=1
# Out:
# Found 155 images belonging to 1 classes.

# %%
x=[]
y=[]

# %%
for label in os.listdir(data_dir):
    print("\t\t\t\t",label)
    index=labels.index(label)
    for img in tqdm.tqdm(os.listdir(os.path.join(data_dir,label))):
        img_path=os.path.join(data_dir,label,img)
        try:
            image=cv.imread(img_path)
            image=cv.resize(image,(256,256))
            x.append(image)
            y.append(index)
        except:
            continue
# Out:
# 				 no
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 336/336 [00:00<00:00, 541.56it/s]
# 				 yes
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 430.87it/s]

# %%
# convert lists to numpy array and normalizze the values
x_data=np.array(x)/255
y_data=np.array(y)

# %%
# split into train,test
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.15)

# %%
# visualize the images
plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(X_train[i+20])
    plt.axis('off')
    plt.title(labels[y_train[i+20]])

# %%
# build cnn model
import tensorflow as tf
from tensorflow import keras

# %%
len(X_train),len(X_test)
# Out:
# (625, 111)

# %%
model=keras.Sequential()
model.add(keras.layers.Conv2D(45,(3,3),activation='relu',input_shape=(256,256,3)))
model.add(keras.layers.MaxPool2D())
model.add(keras.layers.Conv2D(30,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(32,activation='relu'))
model.add(keras.layers.Dense(2,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 20/20 [==============================] - 63s 3s/step - loss: 0.8782 - accuracy: 0.6880 - val_loss: 0.4867 - val_accuracy: 0.7838
# Epoch 2/5
# 20/20 [==============================] - 49s 2s/step - loss: 0.4263 - accuracy: 0.8144 - val_loss: 0.3518 - val_accuracy: 0.8468
# Epoch 3/5
# 20/20 [==============================] - 76s 4s/step - loss: 0.2202 - accuracy: 0.9120 - val_loss: 0.1566 - val_accuracy: 0.9459
# Epoch 4/5
# 20/20 [==============================] - 55s 3s/step - loss: 0.0875 - accuracy: 0.9712 - val_loss: 0.1783 - val_accuracy: 0.8919
# Epoch 5/5
# 20/20 [==============================] - 55s 3s/step - loss: 0.0403 - accuracy: 0.9904 - val_loss: 0.0806 - val_accuracy: 0.9730

# %%
model.evaluate(X_test,y_test)
# Out:
# 4/4 [==============================] - 2s 524ms/step - loss: 0.0806 - accuracy: 0.9730
# [0.08059637248516083, 0.9729729890823364]

# %%
model.save('brain_tumor_model.keras')

# %%
history.history
# Out:
# {'loss': [0.8781771659851074,
#   0.4262528717517853,
#   0.22018127143383026,
#   0.08754667639732361,
#   0.04026147723197937],
#  'accuracy': [0.6880000233650208,
#   0.8144000172615051,
#   0.9120000004768372,
#   0.9711999893188477,
#   0.9904000163078308],
#  'val_loss': [0.4867125451564789,
#   0.35183337330818176,
#   0.15663501620292664,
#   0.1783445030450821,
#   0.08059637248516083],
#  'val_accuracy': [0.7837837934494019,
#   0.8468468189239502,
#   0.9459459185600281,
#   0.8918918967247009,
#   0.9729729890823364]}

# %%
history.epoch
# Out:
# [0, 1, 2, 3, 4]

# %%
seaborn.lineplot(y=history.history['loss'],x=history.epoch)
seaborn.lineplot(y=history.history['accuracy'],x=history.epoch)
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# build reports

# %%
y_p=model.predict(X_test)
# Out:
# 4/4 [==============================] - 2s 502ms/step

# %%
def give_predictions(y_p):
    l=[]
    for i in y_p:
        l.append(np.argmax(i))
    return l

# %%
y_predicted=give_predictions(y_p)

# %%
cm=tf.math.confusion_matrix(y_test,y_predicted)

# %%
import seaborn
from sklearn.metrics import classification_report

# %%
seaborn.heatmap(cm,annot=True,)
plt.xlabel('y_predicted')
plt.ylabel('y_true')
# Out:
# Text(50.722222222222214, 0.5, 'y_true')

# %%
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        63
#            1       0.96      0.98      0.97        48
#
#     accuracy                           0.97       111
#    macro avg       0.97      0.97      0.97       111
# weighted avg       0.97      0.97      0.97       111

# %%
def give_label(arr):
    
    print(labels[np.argmax(arr[0])])

# %%
give_label(y_pre)
# Out:
# yes

# %%
# create a pipeline such that user can enter image and our model will classify
img=cv.imread('no.jpg')
img=cv.resize(img,(256,256))
img=img/255
y_pre=model.predict(
    np.expand_dims(img,0)
    )
give_label(y_pre)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# no

# %%
X_train[0].max()
# Out:
# 1.0

# %%
def predict(img_path):
    img=cv.imread(img_path)
    img=cv.resize(img,(256,256))
    img=img/255
    y_pre=model.predict(
        np.expand_dims(img,0)
        )
    return give_label(y_pre)

# %%
predict('yes1.png'),predict('yes.png')
# Out:
# 1/1 [==============================] - 0s 64ms/step
# yes
# 1/1 [==============================] - 0s 33ms/step
# yes
# (None, None)
